# %%
from pylab import *
import pandas as pd
# %matplotlib inline
execfile('data.py')

# %%
s1 = S.get("voo")
s1 = S.get("vrx")


plot(s1.adjclose)
plot(s2.adjclose)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-234c8abc4c91> in <module>()
#       4
#       5 plot(s1.adjclose)
# ----> 6 plot(s2.adjclose)
#
# NameError: name 's2' is not defined
